# %% [markdown]
# <a href="https://colab.research.google.com/github/Adnan2-a11y/DataCleaning/blob/main/DataCleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('missing_values_dataset.csv')
df.head()
# Out:
#    ID      Name   Age    Salary Department Joining Date
# 0   1  Person_1  50.0   64698.0  Marketing   2015-01-31
# 1   2  Person_2  36.0  110623.0         IT   2015-02-28
# 2   3  Person_3  29.0       NaN    Finance   2015-03-31
# 3   4  Person_4  42.0   55184.0         HR   2015-04-30
# 4   5  Person_5  40.0   72107.0    Finance   2015-05-31

# %%
df.shape
# Out:
# (100, 6)

# %%
df.isnull().sum().sum()
# Out:
# np.int64(45)

# %%
df.isnull().sum()
# Out:
# ID               0
# Name             0
# Age             15
# Salary          12
# Department      10
# Joining Date     8
# dtype: int64

# %%
sns.heatmap(df.isnull())
plt.show()

# %%
df.drop(columns=['Department'])
df.drop(columns=['Salary'])
# Out:
#      ID        Name   Age Department Joining Date
# 0     1    Person_1  50.0  Marketing   2015-01-31
# 1     2    Person_2  36.0         IT   2015-02-28
# 2     3    Person_3  29.0    Finance   2015-03-31
# 3     4    Person_4  42.0         HR   2015-04-30
# 4     5    Person_5  40.0    Finance   2015-05-31
# ..  ...         ...   ...        ...          ...
# 95   96   Person_96  58.0         IT   2022-12-31
# 96   97   Person_97  56.0    Finance   2023-01-31
# 97   98   Person_98   NaN         HR   2023-02-28
# 98   99   Person_99  48.0  Marketing   2023-03-31
# 99  100  Person_100  56.0         IT   2023-04-30
#
# [100 rows x 5 columns]

# %%
df.dropna()
# Out:
#      ID        Name   Age    Salary Department Joining Date
# 0     1    Person_1  50.0   64698.0  Marketing   2015-01-31
# 1     2    Person_2  36.0  110623.0         IT   2015-02-28
# 3     4    Person_4  42.0   55184.0         HR   2015-04-30
# 4     5    Person_5  40.0   72107.0    Finance   2015-05-31
# 5     6    Person_6  44.0  116202.0  Marketing   2015-06-30
# 7     8    Person_8  32.0   45708.0         IT   2015-08-31
# 8     9    Person_9  45.0   79811.0      Sales   2015-09-30
# 9    10   Person_10  57.0   32811.0         IT   2015-10-31
# 10   11   Person_11  45.0   86250.0      Sales   2015-11-30
# 11   12   Person_12  24.0  102082.0         HR   2015-12-31
# 12   13   Person_13  43.0   64754.0  Marketing   2016-01-31
# 13   14   Person_14  23.0   41411.0      Sales   2016-02-29
# 14   15   Person_15  45.0   32911.0         HR   2016-03-31
# 16   17   Person_17  59.0  113763.0         IT   2016-05-31
# 19   20   Person_20  54.0  113879.0         HR   2016-08-31
# ...
